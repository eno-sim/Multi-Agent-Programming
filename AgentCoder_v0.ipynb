# %%
from concurrent.futures import ThreadPoolExecutor
from tqdm import tqdm
import json
import os
from gemini_multiagent_framework import GeminiAgent
from openai_multiagent_framework import OpenAIAgent
from datasets import load_dataset
import pandas as pd
from benchmarks_utils import *

# %% [markdown]
# ## AGENTCODER VERSION 0

# %%
# import the dataset
dataset = load_dataset("openai_humaneval", split="test")
dataset = [entry for entry in dataset]
dataset_chunks = list(chunk_dataset(dataset, 55))

# %%
# %pip install requests
import requests
import json

# URL of the JSON file
url = "https://huggingface.co/datasets/bigcode/humanevalpack/resolve/main/data/python/data/humanevalpack.jsonl"

# Download the content
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Split the content into lines and parse each line as JSON
    data = [json.loads(line) for line in response.text.strip().split('\n')]
    print(f"Successfully loaded {len(data)} entries.")
else:
    print(f"Failed to download the file. Status code: {response.status_code}")
# Out:
# Requirement already satisfied: requests in /home/enosim/anaconda3/envs/nlp-project/lib/python3.10/site-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/enosim/anaconda3/envs/nlp-project/lib/python3.10/site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/enosim/anaconda3/envs/nlp-project/lib/python3.10/site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/enosim/anaconda3/envs/nlp-project/lib/python3.10/site-packages (from requests) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/enosim/anaconda3/envs/nlp-project/lib/python3.10/site-packages (from requests) (2024.6.2)
# Note: you may need to restart the kernel to use updated packages.
# Successfully loaded 164 entries.

# %%
# varying number of test cases
max_attempts = 2
_, code_writer, test_writer = instantiate_agents_gpt(model="gpt-4o-mini")
results = process_dataset(data_chunks[2], chunk_size=25, max_workers=25, max_attempts=max_attempts)
# Out:
# Processing Chunks: 3it [02:51, 57.01s/it]
# Number of valid solutions: 45/54
# Percentage of valid solutions: 83.33%

# %%
def test_accuracy(entry, solution):
    total = len(entry["generated_tests"])
    count = 0
    for test in entry["generated_tests"]:
        try:
            exec(solution + "\n" + test, {"math": math})
            count += 1
        except Exception:
            pass
    return count, total

def create_function_definition(entry):
    # Extract the function signature from the prompt
    prompt = entry["prompt"]
    signature_end = prompt.index(")") + 1
    function_signature = prompt[:signature_end].strip()
    
    # Construct the function definition
    function_def = f"{function_signature}:\n"
    function_def += entry["canonical_solution"]
    
    return function_def

# %%
def dataset_test_accuracy(data):
    overall_count = 0
    overall_total = 0
    for entry in data:
        to_execute = create_function_definition(entry)
        count, total = test_accuracy(entry, to_execute)
        overall_count += count
        overall_total += total
    print(f"Overall accuracy: {overall_count}/{overall_total} ({overall_count/overall_total:.2%})")

# %%
dataset_test_accuracy(data_chunks[2])
# Out:
# Overall accuracy: 224/282 (79.43%)

# %%
exec(to_execute)

# %% [markdown]
# Implementation that is as close as possible to the original Agent Coder as described in the relative article.

# %%
def generate_code_v0(entry, code_writer, prompt_path = "./prompts_v2/codewriter_prompt.md"):
    with open(prompt_path, "r") as f:
        code_writer_prompt = f.read()
    
    requirement = entry["prompt"]
    
    prompt = f"""
{code_writer_prompt}
```python
{requirement}
```
"""
    res = code_writer.process_message(message=prompt)
    code = extract_code(res) 
    entry["generated_code"] = code
    log_file("-" * 20 + "[CODE WRITER PROMPT]"+ "-" * 20 + "\n"+prompt, "log.txt") # DEBUG
    log_file("-" * 20 + "[CODE WRITER RESPONSE]"+ "-" * 20 + "\n"+res, "log.txt") # DEBUG
    return entry

def generate_code_v0_mbpp(entry, code_writer, prompt_path = "./prompts_v2/codewriter_prompt_mbpp.md"):
    with open(prompt_path, "r") as f:
        code_writer_prompt = f.read()
    
    requirement = entry["prompt"]
    
    prompt = f"""
{code_writer_prompt}
{requirement}
Signature of the function: {extract_signature(entry["code"])}
"""
    res = code_writer.process_message(message=prompt)
    code = extract_code(res) 
    entry["generated_code"] = code
    log_file("-" * 20 + "[CODE WRITER PROMPT]"+ "-" * 20 + "\n"+prompt, "log.txt") # DEBUG
    log_file("-" * 20 + "[CODE WRITER RESPONSE]"+ "-" * 20 + "\n"+res, "log.txt") # DEBUG
    return entry


def process_entry(entry, max_attempts = 3):
    entry = generate_code_v0(entry, code_writer)
    entry = generate_tests(entry, test_writer, prompt_path="./prompts_v2/testwriter_prompt.md")
   # entry = validate_code(entry, code_writer, max_attempts=1)
    entry = iterate_tests(entry, code_writer, max_attempts, 
                          prompt_path="./prompts_v2/codewriter_fix.md", test_regeneration=False, intermediate_results=True)
    entry = check_solution(entry)
    entry = generate_report(entry)
    return entry

def get_last_valid_count(entry, current_iteration, count_type):
    for i in range(current_iteration, -1, -1):
        key = f"{count_type}_{i}"
        if key in entry:
            return entry[key]
    return 0  # Return 0 if no valid count is found
## MODIFY THIS FUNCTION TO  PRINT HAVE THE INTERMEDIATE RESULTS OVER MORE ITERATIONS
def process_dataset(dataset, chunk_size, max_workers, max_attempts, intermediate_results=False):
    """
    Processes the dataset in chunks with multithreading.

    Parameters:
    dataset (list): The dataset to be processed.
    chunk_size (int): Number of entries per chunk.
    max_workers (int): Maximum number of worker threads.
    max_attempts (int): Maximum number of attempts for processing each entry.

    Returns:
    list: All processed results.
    """
    all_results = []

    for chunk in tqdm(chunk_dataset(dataset, chunk_size), desc="Processing Chunks"):
        with ThreadPoolExecutor(max_workers=max_workers) as executor:
            results = list(executor.map(lambda entry: process_entry(entry, max_attempts), chunk))
            all_results.extend(results)
    
    if intermediate_results:
        for entry in all_results:
            print(entry["report"])
        for i in range(max_attempts + 1):
            valid_key = f"valid_{i}"
            valid_solutions = [entry for entry in all_results if (valid_key in entry and entry[valid_key]) or 
                                   (valid_key not in entry and entry["solution_valid"])]
            num_true_values = len(valid_solutions)
            accuracy = (num_true_values / len(dataset)) * 100
            # write to a file the intermediate results
            print(f"Iteration {i}: {num_true_values} true values over {len(dataset)} (Accuracy: {accuracy:.2f}%)\n")
            
            total_test_count = sum([get_last_valid_count(entry, i, "test_count") for entry in all_results])
            overall_count = sum([get_last_valid_count(entry, i, "test_total") for entry in all_results])
    
    # Print the accuracy for the iteration of the tests
            if overall_count > 0:
                print(f"Test accuracy for iteration {i}: {total_test_count}/{overall_count} ({total_test_count/overall_count*100:.2f}%)")
            else:
                print(f"Test accuracy for iteration {i}: No valid tests found")
    
        return all_results
            
    valid_solutions = [entry for entry in all_results if entry["solution_valid"]]
    # Print the number of valid solutions as a percentage of the total number of solutions
    print(f"Number of valid solutions: {len(valid_solutions)}/{len(all_results)}")
    print(f"Percentage of valid solutions: {len(valid_solutions) / len(all_results) * 100:.2f}%")

    return all_results


def process_entry_mbpp(entry, max_attempts = 3):
    entry = generate_code_v0(entry, code_writer, prompt_path="./prompts_v2/codewriter_prompt_mbpp.md")
    entry = generate_tests_mbpp(entry, test_writer, prompt_path="./prompts_v2/testwriter_prompt_mbpp.md")
   # entry = validate_code(entry, code_writer, max_attempts=1)
    entry = iterate_tests(entry, code_writer, max_attempts,
                          prompt_path="./prompts_v2/codewriter_fix_mbpp.md", 
                          test_regeneration=False, intermediate_results=True, mbpp = True)
    entry = check_solution_mbpp(entry)
    entry = generate_report(entry)
    return entry


def process_dataset_mbpp(dataset, chunk_size, max_workers, max_attempts, intermediate_results=False):
    """
    Processes the dataset in chunks with multithreading.

    Parameters:
    dataset (list): The dataset to be processed.
    chunk_size (int): Number of entries per chunk.
    max_workers (int): Maximum number of worker threads.
    max_attempts (int): Maximum number of attempts for processing each entry.

    Returns:
    list: All processed results.
    """
    all_results = []

    for chunk in tqdm(chunk_dataset(dataset, chunk_size), desc="Processing Chunks"):
        with ThreadPoolExecutor(max_workers=max_workers) as executor:
            results = list(executor.map(lambda entry: process_entry_mbpp(entry, max_attempts), chunk))
            all_results.extend(results)
            
    for entry in all_results:
        print(entry["report"])
        
    if intermediate_results:
        for i in range(max_attempts + 1):
            valid_key = f"valid_{i}"
            valid_solutions = [entry for entry in all_results if (valid_key in entry and entry[valid_key]) or 
                                   (valid_key not in entry and entry["solution_valid"])]
            num_true_values = len(valid_solutions)
            accuracy = (num_true_values / len(dataset)) * 100
            # write to a file the intermediate results
            print(f"Iteration {i}: {num_true_values} true values over {len(dataset)} (Accuracy: {accuracy:.2f}%)\n")
        return all_results

    valid_solutions = [entry for entry in all_results if entry["solution_valid"]]
    # Print the number of valid solutions as a percentage of the total number of solutions
    print(f"Number of valid solutions: {len(valid_solutions)}/{len(all_results)}")
    print(f"Percentage of valid solutions: {len(valid_solutions) / len(all_results) * 100:.2f}%")

    return all_results

# %% [markdown]
# ## HUMANEVAL DATASET

# %%
dataset = load_dataset("openai_humaneval", split="test")
dataset = [entry for entry in dataset]
dataset_chunks = list(chunk_dataset(dataset, 55))

# %%
# varying number of test cases
max_attempts = 3
_, code_writer, test_writer = instantiate_agents_gpt(model="gpt-4o-mini")
results = process_dataset(dataset_chunks[2], chunk_size=25, max_workers=25, max_attempts=max_attempts, intermediate_results=True)
# Out:
# Processing Chunks: 3it [02:00, 40.08s/it]
# Report:
# - Total tests: 5
# - Passed tests: 4
# - Failed tests: 1
# - Percentage passed: 80.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 4
# - Failed tests: 1
# - Percentage passed: 80.0%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 5
# - Passed tests: 4
# - Failed tests: 1
# - Percentage passed: 80.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 5
# - Passed tests: 1
# - Failed tests: 4
# - Percentage passed: 20.0%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 5
# - Passed tests: 4
# - Failed tests: 1
# - Percentage passed: 80.0%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 3
# - Failed tests: 2
# - Percentage passed: 60.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 2
# - Failed tests: 3
# - Percentage passed: 40.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 3
# - Failed tests: 2
# - Percentage passed: 60.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 4
# - Failed tests: 1
# - Percentage passed: 80.0%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 5
# - Passed tests: 4
# - Failed tests: 1
# - Percentage passed: 80.0%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 4
# - Failed tests: 1
# - Percentage passed: 80.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 3
# - Failed tests: 2
# - Percentage passed: 60.0%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 4
# - Failed tests: 1
# - Percentage passed: 80.0%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 5
# - Passed tests: 4
# - Failed tests: 1
# - Percentage passed: 80.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 4
# - Failed tests: 1
# - Percentage passed: 80.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 3
# - Failed tests: 2
# - Percentage passed: 60.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 3
# - Failed tests: 2
# - Percentage passed: 60.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 1
# - Failed tests: 4
# - Percentage passed: 20.0%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 4
# - Failed tests: 1
# - Percentage passed: 80.0%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 5
# - Passed tests: 2
# - Failed tests: 3
# - Percentage passed: 40.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 10
# - Passed tests: 10
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 4
# - Failed tests: 1
# - Percentage passed: 80.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 3
# - Failed tests: 2
# - Percentage passed: 60.0%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 5
# - Passed tests: 4
# - Failed tests: 1
# - Percentage passed: 80.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 3
# - Failed tests: 2
# - Percentage passed: 60.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 4
# - Failed tests: 1
# - Percentage passed: 80.0%
#
# Solution is valid: False
#
# Iteration 0: 42 true values over 54 (Accuracy: 77.78%)
#
# Test accuracy for iteration 0: 235/275 (85.45%)
# Iteration 1: 41 true values over 54 (Accuracy: 75.93%)
#
# Test accuracy for iteration 1: 235/275 (85.45%)
# Iteration 2: 41 true values over 54 (Accuracy: 75.93%)
#
# Test accuracy for iteration 2: 235/275 (85.45%)
# Iteration 3: 40 true values over 54 (Accuracy: 74.07%)
#
# Test accuracy for iteration 3: 235/275 (85.45%)

# %% [markdown]
# ### Experiments on the last chunk

# %% [markdown]
# #### Varying the number of generated test cases (from the prompt)

# %%
# varying number of test cases
max_attempts = 7
_, code_writer, test_writer = instantiate_agents_gpt(model="gpt-4o-mini")
results = process_dataset(dataset_chunks[2], chunk_size=20, max_workers=20, max_attempts=max_attempts, intermediate_results=True)
# Out:
# Processing Chunks: 3it [03:58, 79.67s/it]
# Report:
# - Total tests: 14
# - Passed tests: 14
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 10
# - Passed tests: 10
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 13
# - Passed tests: 12
# - Failed tests: 1
# - Percentage passed: 92.3076923076923%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 29
# - Passed tests: 17
# - Failed tests: 12
# - Percentage passed: 58.620689655172406%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 13
# - Passed tests: 10
# - Failed tests: 3
# - Percentage passed: 76.92307692307693%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 15
# - Passed tests: 14
# - Failed tests: 1
# - Percentage passed: 93.33333333333333%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 15
# - Passed tests: 9
# - Failed tests: 6
# - Percentage passed: 60.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 15
# - Passed tests: 8
# - Failed tests: 7
# - Percentage passed: 53.333333333333336%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 15
# - Passed tests: 12
# - Failed tests: 3
# - Percentage passed: 80.0%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 15
# - Passed tests: 14
# - Failed tests: 1
# - Percentage passed: 93.33333333333333%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 10
# - Passed tests: 10
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 12
# - Passed tests: 10
# - Failed tests: 2
# - Percentage passed: 83.33333333333334%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 10
# - Passed tests: 9
# - Failed tests: 1
# - Percentage passed: 90.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 15
# - Passed tests: 5
# - Failed tests: 10
# - Percentage passed: 33.33333333333333%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 15
# - Passed tests: 15
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 15
# - Passed tests: 14
# - Failed tests: 1
# - Percentage passed: 93.33333333333333%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 13
# - Passed tests: 13
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 15
# - Passed tests: 14
# - Failed tests: 1
# - Percentage passed: 93.33333333333333%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 13
# - Passed tests: 9
# - Failed tests: 4
# - Percentage passed: 69.23076923076923%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 15
# - Passed tests: 6
# - Failed tests: 9
# - Percentage passed: 40.0%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 14
# - Passed tests: 1
# - Failed tests: 13
# - Percentage passed: 7.142857142857142%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 15
# - Passed tests: 14
# - Failed tests: 1
# - Percentage passed: 93.33333333333333%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 13
# - Passed tests: 11
# - Failed tests: 2
# - Percentage passed: 84.61538461538461%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 15
# - Passed tests: 9
# - Failed tests: 6
# - Percentage passed: 60.0%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 15
# - Passed tests: 12
# - Failed tests: 3
# - Percentage passed: 80.0%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 12
# - Passed tests: 7
# - Failed tests: 5
# - Percentage passed: 58.333333333333336%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 14
# - Passed tests: 14
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 15
# - Passed tests: 15
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 10
# - Passed tests: 10
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 11
# - Passed tests: 6
# - Failed tests: 5
# - Percentage passed: 54.54545454545454%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 15
# - Passed tests: 11
# - Failed tests: 4
# - Percentage passed: 73.33333333333333%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 15
# - Passed tests: 15
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 10
# - Passed tests: 4
# - Failed tests: 6
# - Percentage passed: 40.0%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 10
# - Passed tests: 3
# - Failed tests: 7
# - Percentage passed: 30.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 15
# - Passed tests: 14
# - Failed tests: 1
# - Percentage passed: 93.33333333333333%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 11
# - Passed tests: 1
# - Failed tests: 10
# - Percentage passed: 9.090909090909092%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 10
# - Passed tests: 8
# - Failed tests: 2
# - Percentage passed: 80.0%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 10
# - Passed tests: 5
# - Failed tests: 5
# - Percentage passed: 50.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 13
# - Passed tests: 13
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 15
# - Passed tests: 9
# - Failed tests: 6
# - Percentage passed: 60.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 15
# - Passed tests: 15
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 15
# - Passed tests: 13
# - Failed tests: 2
# - Percentage passed: 86.66666666666667%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 10
# - Passed tests: 10
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 12
# - Passed tests: 8
# - Failed tests: 4
# - Percentage passed: 66.66666666666666%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 15
# - Passed tests: 14
# - Failed tests: 1
# - Percentage passed: 93.33333333333333%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 10
# - Passed tests: 9
# - Failed tests: 1
# - Percentage passed: 90.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 15
# - Passed tests: 15
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 15
# - Passed tests: 14
# - Failed tests: 1
# - Percentage passed: 93.33333333333333%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 10
# - Passed tests: 9
# - Failed tests: 1
# - Percentage passed: 90.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 14
# - Passed tests: 8
# - Failed tests: 6
# - Percentage passed: 57.14285714285714%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 15
# - Passed tests: 5
# - Failed tests: 10
# - Percentage passed: 33.33333333333333%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 15
# - Passed tests: 11
# - Failed tests: 4
# - Percentage passed: 73.33333333333333%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 7
# - Passed tests: 2
# - Failed tests: 5
# - Percentage passed: 28.57142857142857%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 13
# - Passed tests: 13
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: False
#
# Iteration 0: 43 true values over 54 (Accuracy: 79.63%)
#
# Iteration 1: 40 true values over 54 (Accuracy: 74.07%)
#
# Iteration 2: 40 true values over 54 (Accuracy: 74.07%)
#
# Iteration 3: 38 true values over 54 (Accuracy: 70.37%)
#
# Iteration 4: 41 true values over 54 (Accuracy: 75.93%)
#
# Iteration 5: 40 true values over 54 (Accuracy: 74.07%)
#
# Iteration 6: 35 true values over 54 (Accuracy: 64.81%)
#
# Iteration 7: 35 true values over 54 (Accuracy: 64.81%)

# %% [markdown]
# Performance degrades through the optimization loop. The reason could be that many test cases are wrong and therefore drive the refinement of the code in the wrong direction

# %% [markdown]
# #### Fixed test cases

# %%
# with fixed test cases

max_attempts = 7
_, code_writer, test_writer = instantiate_agents_gpt(model="gpt-4o-mini")
results = process_dataset(dataset_chunks[2], chunk_size=20, max_workers=20, max_attempts=max_attempts, intermediate_results=True)
# Out:
# Processing Chunks: 3it [03:23, 67.69s/it]
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 13
# - Passed tests: 1
# - Failed tests: 12
# - Percentage passed: 7.6923076923076925%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 4
# - Failed tests: 1
# - Percentage passed: 80.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 4
# - Failed tests: 1
# - Percentage passed: 80.0%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 5
# - Passed tests: 3
# - Failed tests: 2
# - Percentage passed: 60.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 4
# - Failed tests: 1
# - Percentage passed: 80.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 4
# - Failed tests: 1
# - Percentage passed: 80.0%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 5
# - Passed tests: 2
# - Failed tests: 3
# - Percentage passed: 40.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 4
# - Failed tests: 1
# - Percentage passed: 80.0%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 4
# - Failed tests: 1
# - Percentage passed: 80.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 3
# - Failed tests: 2
# - Percentage passed: 60.0%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 4
# - Failed tests: 1
# - Percentage passed: 80.0%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 5
# - Passed tests: 3
# - Failed tests: 2
# - Percentage passed: 60.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 4
# - Failed tests: 1
# - Percentage passed: 80.0%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 3
# - Failed tests: 2
# - Percentage passed: 60.0%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 5
# - Passed tests: 3
# - Failed tests: 2
# - Percentage passed: 60.0%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 1
# - Failed tests: 4
# - Percentage passed: 20.0%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 5
# - Passed tests: 4
# - Failed tests: 1
# - Percentage passed: 80.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 3
# - Failed tests: 2
# - Percentage passed: 60.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 4
# - Failed tests: 1
# - Percentage passed: 80.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 3
# - Failed tests: 2
# - Percentage passed: 60.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 4
# - Failed tests: 1
# - Percentage passed: 80.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 4
# - Failed tests: 1
# - Percentage passed: 80.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 4
# - Failed tests: 1
# - Percentage passed: 80.0%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 5
# - Passed tests: 3
# - Failed tests: 2
# - Percentage passed: 60.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 3
# - Failed tests: 2
# - Percentage passed: 60.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
# Iteration 0: 43 true values over 54 (Accuracy: 79.63%)
#
# Iteration 1: 41 true values over 54 (Accuracy: 75.93%)
#
# Iteration 2: 44 true values over 54 (Accuracy: 81.48%)
#
# Iteration 3: 43 true values over 54 (Accuracy: 79.63%)
#
# Iteration 4: 41 true values over 54 (Accuracy: 75.93%)
#
# Iteration 5: 45 true values over 54 (Accuracy: 83.33%)
#
# Iteration 6: 41 true values over 54 (Accuracy: 75.93%)
#
# Iteration 7: 41 true values over 54 (Accuracy: 75.93%)

# %%
print("Total tokens code writer: {}".format(code_writer.total_tokens))
print("Total tokens test writer: {}".format(test_writer.total_tokens))
print("Total tokens: {}".format(code_writer.total_tokens + test_writer.total_tokens))
print("Test writer API calls: {}".format(test_writer.api_calls))
print("Code writer API calls: {}".format(code_writer.api_calls))
print("Total API calls: {}".format(code_writer.api_calls + test_writer.api_calls))
# Out:
# Total tokens code writer: 447275
# Total tokens test writer: 43072
# Total tokens: 490347
# Test writer API calls: 54
# Code writer API calls: 245
# Total API calls: 299

# %%
# with fixed test cases

max_attempts = 5
_, code_writer, test_writer = instantiate_agents_gpt(model="gpt-4o-mini")
results = process_dataset(dataset_chunks[0], chunk_size=20, max_workers=20, max_attempts=max_attempts, intermediate_results=True)
# Out:
# Processing Chunks: 3it [02:29, 49.67s/it]
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 4
# - Failed tests: 1
# - Percentage passed: 80.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 4
# - Failed tests: 1
# - Percentage passed: 80.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 3
# - Failed tests: 2
# - Percentage passed: 60.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 12
# - Passed tests: 9
# - Failed tests: 3
# - Percentage passed: 75.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 4
# - Failed tests: 1
# - Percentage passed: 80.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 4
# - Failed tests: 1
# - Percentage passed: 80.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 4
# - Failed tests: 1
# - Percentage passed: 80.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 12
# - Passed tests: 10
# - Failed tests: 2
# - Percentage passed: 83.33333333333334%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 3
# - Failed tests: 2
# - Percentage passed: 60.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 4
# - Failed tests: 1
# - Percentage passed: 80.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 4
# - Failed tests: 1
# - Percentage passed: 80.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 12
# - Passed tests: 10
# - Failed tests: 2
# - Percentage passed: 83.33333333333334%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 5
# - Passed tests: 4
# - Failed tests: 1
# - Percentage passed: 80.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 4
# - Failed tests: 1
# - Percentage passed: 80.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 4
# - Failed tests: 1
# - Percentage passed: 80.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 10
# - Passed tests: 5
# - Failed tests: 5
# - Percentage passed: 50.0%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
# Iteration 0: 54 true values over 55 (Accuracy: 98.18%)
#
# Iteration 1: 52 true values over 55 (Accuracy: 94.55%)
#
# Iteration 2: 50 true values over 55 (Accuracy: 90.91%)
#
# Iteration 3: 52 true values over 55 (Accuracy: 94.55%)
#
# Iteration 4: 52 true values over 55 (Accuracy: 94.55%)
#
# Iteration 5: 52 true values over 55 (Accuracy: 94.55%)

# %%
print("Total tokens code writer: {}".format(code_writer.total_tokens))
print("Total tokens test writer: {}".format(test_writer.total_tokens))
print("Total tokens: {}".format(code_writer.total_tokens + test_writer.total_tokens))
print("Test writer API calls: {}".format(test_writer.api_calls))
print("Code writer API calls: {}".format(code_writer.api_calls))
print("Total API calls: {}".format(code_writer.api_calls + test_writer.api_calls))
# Out:
# Total tokens code writer: 233130
# Total tokens test writer: 40704
# Total tokens: 273834
# Test writer API calls: 55
# Code writer API calls: 144
# Total API calls: 199

# %%
# with fixed test cases
max_attempts = 5
_, code_writer, test_writer = instantiate_agents_gpt(model="gpt-4o-mini")
results = process_dataset(dataset_chunks[1], chunk_size=20, max_workers=20, max_attempts=max_attempts, intermediate_results=True)
# Out:
# Processing Chunks: 3it [02:51, 57.01s/it]
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 4
# - Failed tests: 1
# - Percentage passed: 80.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 0
# - Failed tests: 5
# - Percentage passed: 0.0%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 3
# - Failed tests: 2
# - Percentage passed: 60.0%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 2
# - Failed tests: 3
# - Percentage passed: 40.0%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 2
# - Failed tests: 3
# - Percentage passed: 40.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 2
# - Failed tests: 3
# - Percentage passed: 40.0%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 5
# - Passed tests: 4
# - Failed tests: 1
# - Percentage passed: 80.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 1
# - Failed tests: 4
# - Percentage passed: 20.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 3
# - Failed tests: 2
# - Percentage passed: 60.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 9
# - Passed tests: 7
# - Failed tests: 2
# - Percentage passed: 77.77777777777779%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 4
# - Failed tests: 1
# - Percentage passed: 80.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 1
# - Failed tests: 4
# - Percentage passed: 20.0%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 4
# - Failed tests: 1
# - Percentage passed: 80.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 4
# - Failed tests: 1
# - Percentage passed: 80.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 5
# - Passed tests: 4
# - Failed tests: 1
# - Percentage passed: 80.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 5
# - Passed tests: 4
# - Failed tests: 1
# - Percentage passed: 80.0%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 4
# - Failed tests: 1
# - Percentage passed: 80.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 4
# - Failed tests: 1
# - Percentage passed: 80.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 3
# - Failed tests: 2
# - Percentage passed: 60.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 5
# - Passed tests: 1
# - Failed tests: 4
# - Percentage passed: 20.0%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 5
# - Passed tests: 5
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
# Iteration 0: 42 true values over 55 (Accuracy: 76.36%)
#
# Iteration 1: 46 true values over 55 (Accuracy: 83.64%)
#
# Iteration 2: 46 true values over 55 (Accuracy: 83.64%)
#
# Iteration 3: 45 true values over 55 (Accuracy: 81.82%)
#
# Iteration 4: 44 true values over 55 (Accuracy: 80.00%)
#
# Iteration 5: 45 true values over 55 (Accuracy: 81.82%)

# %%
print("Total tokens code writer: {}".format(code_writer.total_tokens))
print("Total tokens test writer: {}".format(test_writer.total_tokens))
print("Total tokens: {}".format(code_writer.total_tokens + test_writer.total_tokens))
print("Test writer API calls: {}".format(test_writer.api_calls))
print("Code writer API calls: {}".format(code_writer.api_calls))
print("Total API calls: {}".format(code_writer.api_calls + test_writer.api_calls))
# Out:
# Total tokens code writer: 279007
# Total tokens test writer: 42102
# Total tokens: 321109
# Test writer API calls: 55
# Code writer API calls: 165
# Total API calls: 220

# %% [markdown]
# ## HumanEval Results

# %% [markdown]
# | Model          | it. 0 |  it. 1  |  it. 2  |  Total tokens |
# | -------------- | ----- | ------- | ------- | --------------|
# | GPT 4o-mini | 84.8%| 84.8%  | 85.3%  | 523544           |

# %% [markdown]
# ### Results for a longer run

# %% [markdown]
# | Model                   | it. 0  |  it. 1  |  it. 2  |  it. 3  |  it. 4  |  it. 5  |  it. 6  |
# | ----------------------- | ------ | ------- | ------- | ------- | ------- | ------- | ------- |
# |   GPT 4o-mini          | 79.63% | 75.93%  | 81.48%  | 79.63%  | 75.93%  | 83.33%  | 75.93%  |

# %% [markdown]
# ## MBPP DATASET

# %%
# MBPP dataset preprocessing, import from hugging face
mbpp_dataset = load_dataset("mbpp",  "sanitized", split="test")
mbpp_dataset = [entry for entry in mbpp_dataset]
# apply check_solution_mbpp to all entries in the dataset and print the indices of the entries for which entry["solution_valid"] is False
results = [check_correctness(entry) for entry in mbpp_dataset]
# remove the entries for which entry["solution_valid"] is False
mbpp_dataset = [entry for entry in mbpp_dataset if entry["correct"]]

# %%
mbpp_dataset_chunks = list(chunk_dataset(mbpp_dataset, 53))

# %% [markdown]
# ### Experiments on the first chunk

# %%
max_attempts = 5
_, code_writer, test_writer = instantiate_agents_gpt(model="gpt-4o-mini")

results = process_dataset_mbpp(mbpp_dataset_chunks[0], chunk_size=15, max_workers=15, 
                               max_attempts=max_attempts, intermediate_results=True)
# Out:
# Processing Chunks: 0it [00:08, ?it/s]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[27], line 4
#       1 max_attempts = 5
#       2 _, code_writer, test_writer = instantiate_agents_gpt(model="gpt-4o-mini")
# ----> 4 results = process_dataset_mbpp(mbpp_dataset_chunks[0], chunk_size=15, max_workers=15,
#       5                                max_attempts=max_attempts, intermediate_results=True)
#
# Cell In[9], line 136, in process_dataset_mbpp(dataset, chunk_size, max_workers, max_attempts, intermediate_results)
#     134 for chunk in tqdm(chunk_dataset(dataset, chunk_size), desc="Processing Chunks"):
#     135     with ThreadPoolExecutor(max_workers=max_workers) as executor:
# --> 136         results = list(executor.map(lambda entry: process_entry_mbpp(entry, max_attempts), chunk))
#     137         all_results.extend(results)
#     139 for entry in all_results:
#
# File ~/anaconda3/envs/nlp-project/lib/python3.10/concurrent/futures/_base.py:621, in Executor.map.<locals>.result_iterator()
#     618 while fs:
#     619     # Careful not to keep a reference to the popped future
#     620     if timeout is None:
# --> 621         yield _result_or_cancel(fs.pop())
#     622     else:
#     623         yield _result_or_cancel(fs.pop(), end_time - time.monotonic())
#
# File ~/anaconda3/envs/nlp-project/lib/python3.10/concurrent/futures/_base.py:319, in _result_or_cancel(***failed resolving arguments***)
#     317 try:
#     318     try:
# --> 319         return fut.result(timeout)
#     320     finally:
#     321         fut.cancel()
#
# File ~/anaconda3/envs/nlp-project/lib/python3.10/concurrent/futures/_base.py:458, in Future.result(self, timeout)
#     456     raise CancelledError()
#     457 elif self._state == FINISHED:
# --> 458     return self.__get_result()
#     459 else:
#     460     raise TimeoutError()
#
# File ~/anaconda3/envs/nlp-project/lib/python3.10/concurrent/futures/_base.py:403, in Future.__get_result(self)
#     401 if self._exception:
#     402     try:
# --> 403         raise self._exception
#     404     finally:
#     405         # Break a reference cycle with the exception in self._exception
#     406         self = None
#
# File ~/anaconda3/envs/nlp-project/lib/python3.10/concurrent/futures/thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# Cell In[9], line 136, in process_dataset_mbpp.<locals>.<lambda>(entry)
#     134 for chunk in tqdm(chunk_dataset(dataset, chunk_size), desc="Processing Chunks"):
#     135     with ThreadPoolExecutor(max_workers=max_workers) as executor:
# --> 136         results = list(executor.map(lambda entry: process_entry_mbpp(entry, max_attempts), chunk))
#     137         all_results.extend(results)
#     139 for entry in all_results:
#
# Cell In[9], line 111, in process_entry_mbpp(entry, max_attempts)
#     109  entry = generate_tests_mbpp(entry, test_writer, prompt_path="./prompts_v2/testwriter_prompt_mbpp.md")
#     110 # entry = validate_code(entry, code_writer, max_attempts=1)
# --> 111  entry = iterate_tests(entry, code_writer, max_attempts,
#     112                        prompt_path="./prompts_v2/codewriter_fix.md",
#     113                        test_regeneration=False, intermediate_results=True, mbpp = True)
#     114  entry = check_solution_mbpp(entry)
#     115  entry = generate_report(entry)
#
# File ~/Desktop/Deep Learning/inture/inture/benchmarks_utils.py:166, in iterate_tests(entry, code_writer, max_attempts, prompt_path, test_writer, test_regeneration, intermediate_results, reg_prompt_path, mbpp)
#     164 if intermediate_results:
#     165     if mbpp:
# --> 166         entry = check_solution_intermediate_results_mbpp(entry, code, iteration)
#     167     else:
#     168         entry = check_solution_intermediate_results(entry, code, iteration)
#
# File ~/Desktop/Deep Learning/inture/inture/benchmarks_utils.py:443, in check_solution_intermediate_results_mbpp(entry, code, iteration)
#     442 def check_solution_intermediate_results_mbpp(entry, code, iteration):
# --> 443     tests = ["\n".join(entry["test_setup_code"]) + "\n" + test for test in entry["test_list"]]
#     444     valid_key = f"valid_{iteration}"
#     445     valid = is_test_valid_mbpp(code, tests)
#
# File ~/Desktop/Deep Learning/inture/inture/benchmarks_utils.py:443, in <listcomp>(.0)
#     442 def check_solution_intermediate_results_mbpp(entry, code, iteration):
# --> 443     tests = ["\n".join(entry["test_setup_code"]) + "\n" + test for test in entry["test_list"]]
#     444     valid_key = f"valid_{iteration}"
#     445     valid = is_test_valid_mbpp(code, tests)
#
# KeyError: 'test_setup_code'

# %%
max_attempts = 5
_, code_writer, test_writer = instantiate_agents_gpt(model="gpt-4o-mini")

results = process_dataset_mbpp(mbpp_dataset_chunks[1], chunk_size=20, max_workers=20, 
                               max_attempts=max_attempts, intermediate_results=True)
# Out:
# Processing Chunks: 3it [02:59, 59.87s/it]
# Report:
# - Total tests: 8
# - Passed tests: 8
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 8
# - Passed tests: 0
# - Failed tests: 8
# - Percentage passed: 0.0%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 8
# - Passed tests: 0
# - Failed tests: 8
# - Percentage passed: 0.0%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 8
# - Passed tests: 0
# - Failed tests: 8
# - Percentage passed: 0.0%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 8
# - Passed tests: 0
# - Failed tests: 8
# - Percentage passed: 0.0%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 8
# - Passed tests: 0
# - Failed tests: 8
# - Percentage passed: 0.0%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 8
# - Passed tests: 8
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 8
# - Passed tests: 7
# - Failed tests: 1
# - Percentage passed: 87.5%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 8
# - Passed tests: 8
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 8
# - Passed tests: 0
# - Failed tests: 8
# - Percentage passed: 0.0%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 8
# - Passed tests: 0
# - Failed tests: 8
# - Percentage passed: 0.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 8
# - Passed tests: 0
# - Failed tests: 8
# - Percentage passed: 0.0%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 8
# - Passed tests: 0
# - Failed tests: 8
# - Percentage passed: 0.0%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 8
# - Passed tests: 0
# - Failed tests: 8
# - Percentage passed: 0.0%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 8
# - Passed tests: 0
# - Failed tests: 8
# - Percentage passed: 0.0%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 8
# - Passed tests: 0
# - Failed tests: 8
# - Percentage passed: 0.0%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 8
# - Passed tests: 0
# - Failed tests: 8
# - Percentage passed: 0.0%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 8
# - Passed tests: 0
# - Failed tests: 8
# - Percentage passed: 0.0%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 8
# - Passed tests: 8
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 8
# - Passed tests: 4
# - Failed tests: 4
# - Percentage passed: 50.0%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 8
# - Passed tests: 7
# - Failed tests: 1
# - Percentage passed: 87.5%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 8
# - Passed tests: 0
# - Failed tests: 8
# - Percentage passed: 0.0%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 8
# - Passed tests: 0
# - Failed tests: 8
# - Percentage passed: 0.0%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 8
# - Passed tests: 0
# - Failed tests: 8
# - Percentage passed: 0.0%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 8
# - Passed tests: 0
# - Failed tests: 8
# - Percentage passed: 0.0%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 8
# - Passed tests: 2
# - Failed tests: 6
# - Percentage passed: 25.0%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 8
# - Passed tests: 8
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 8
# - Passed tests: 8
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 8
# - Passed tests: 0
# - Failed tests: 8
# - Percentage passed: 0.0%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 8
# - Passed tests: 8
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 8
# - Passed tests: 0
# - Failed tests: 8
# - Percentage passed: 0.0%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 8
# - Passed tests: 0
# - Failed tests: 8
# - Percentage passed: 0.0%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 8
# - Passed tests: 8
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 8
# - Passed tests: 5
# - Failed tests: 3
# - Percentage passed: 62.5%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 8
# - Passed tests: 0
# - Failed tests: 8
# - Percentage passed: 0.0%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 8
# - Passed tests: 0
# - Failed tests: 8
# - Percentage passed: 0.0%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 8
# - Passed tests: 6
# - Failed tests: 2
# - Percentage passed: 75.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 8
# - Passed tests: 0
# - Failed tests: 8
# - Percentage passed: 0.0%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 8
# - Passed tests: 0
# - Failed tests: 8
# - Percentage passed: 0.0%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 8
# - Passed tests: 0
# - Failed tests: 8
# - Percentage passed: 0.0%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 8
# - Passed tests: 0
# - Failed tests: 8
# - Percentage passed: 0.0%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 8
# - Passed tests: 0
# - Failed tests: 8
# - Percentage passed: 0.0%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 8
# - Passed tests: 0
# - Failed tests: 8
# - Percentage passed: 0.0%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 8
# - Passed tests: 0
# - Failed tests: 8
# - Percentage passed: 0.0%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 8
# - Passed tests: 6
# - Failed tests: 2
# - Percentage passed: 75.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 8
# - Passed tests: 0
# - Failed tests: 8
# - Percentage passed: 0.0%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 8
# - Passed tests: 0
# - Failed tests: 8
# - Percentage passed: 0.0%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 8
# - Passed tests: 8
# - Failed tests: 0
# - Percentage passed: 100.0%
#
# Solution is valid: True
#
#
# Report:
# - Total tests: 8
# - Passed tests: 0
# - Failed tests: 8
# - Percentage passed: 0.0%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 8
# - Passed tests: 0
# - Failed tests: 8
# - Percentage passed: 0.0%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 8
# - Passed tests: 0
# - Failed tests: 8
# - Percentage passed: 0.0%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 8
# - Passed tests: 0
# - Failed tests: 8
# - Percentage passed: 0.0%
#
# Solution is valid: False
#
#
# Report:
# - Total tests: 8
# - Passed tests: 0
# - Failed tests: 8
# - Percentage passed: 0.0%
#
# Solution is valid: False
#
# Iteration 0: 13 true values over 53 (Accuracy: 24.53%)
#
# Iteration 1: 11 true values over 53 (Accuracy: 20.75%)
#
# Iteration 2: 12 true values over 53 (Accuracy: 22.64%)
#
# Iteration 3: 11 true values over 53 (Accuracy: 20.75%)
#
# Iteration 4: 11 true values over 53 (Accuracy: 20.75%)
#
# Iteration 5: 11 true values over 53 (Accuracy: 20.75%)

# %%
print("Total tokens code writer: {}".format(code_writer.total_tokens))
print("Total tokens test writer: {}".format(test_writer.total_tokens))
print("Total tokens: {}".format(code_writer.total_tokens + test_writer.total_tokens))
print("Code writer API calls: {}".format(test_writer.api_calls))
print("Code writer API calls: {}".format(code_writer.api_calls))
print("Total API calls: {}".format(code_writer.api_calls + test_writer.api_calls))
# Out:
# Total tokens code writer: 528394
# Total tokens test writer: 43969
# Total tokens: 572363
# Code writer API calls: 53
# Code writer API calls: 280
# Total API calls: 333

# %%
max_attempts = 5
_, code_writer, test_writer = instantiate_agents_gpt(model="gpt-4o-mini")

results = process_dataset_mbpp(mbpp_dataset_chunks[2], chunk_size=20, max_workers=20, 
                               max_attempts=max_attempts, intermediate_results=True)
